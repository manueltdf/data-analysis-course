# %%
#ejercicio 1

monto = 45750

if monto < 1000:
    categoria = "micro transacción"

elif monto < 10000:
    categoria = "transacción estándar"

elif monto < 100000:
    categoria = "transacción importante"

else:
    categoria = "transacción de alto valor"

print(clasificacion)
# Out:
# Monto: $45750 - Categoría: transacción importante

# %%
#ejercicio 2

precios = [8500, 32000, 15900, 7200, 54000, 12300]
impuesto = 0.19
total = 0
for p in precios:
    precio_con_impuesto = p * (1+impuesto)
    total += precio_con_impuesto
    print(f"Precio base: {p} --> Precio final: {precio_con_impuesto:.1f}")

print(f"Total general: ${total}")
# Out:
# Precio base: 8500 --> Precio final: 10115.0
# Precio base: 32000 --> Precio final: 38080.0
# Precio base: 15900 --> Precio final: 18921.0
# Precio base: 7200 --> Precio final: 8568.0
# Precio base: 54000 --> Precio final: 64260.0
# Precio base: 12300 --> Precio final: 14637.0
# Total general: $154581.0

# %%
#ejercicio 3

inventario = {
    "NB-001": {"nombre": "Notebook Pro", "precio": 320000, "stock": 5},
    "MS-002": {"nombre": "Mouse Inalámbrico", "precio": 8500, "stock": 42},
    "MN-003": {"nombre": "Monitor 24\"", "precio": 210000, "stock": 0},
    "TC-004": {"nombre": "Teclado Mecánico", "precio": 45000, "stock": 12},
}
codigo_busqueda = "MN-003"

print(inventario.get(codigo_busqueda, "no encontrado"))
# Out:
# {'nombre': 'Monitor 24"', 'precio': 210000, 'stock': 0}

# %%
#ejercicio 4

ventas = [23000, 87000, 45000, 102000, 31500, 68000, 49000, 95000, 12000, 74000]
meta = 50000
sobre_meta = []
bajo_meta = []

for v in ventas:
    if v >= meta:
        sobre_meta.append(v)
    else:
        bajo_meta.append(v)

print(len(sobre_meta))
print(len(bajo_meta))

print(sum(sobre_meta))
print(sum(bajo_meta))
# Out:
# 5
# 5
# 426000
# 160500

# %%
#ejercicio 5
