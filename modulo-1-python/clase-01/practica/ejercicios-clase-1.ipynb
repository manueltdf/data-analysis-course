# %%
#ejercicio 1
cliente = "Manuel Vazquez"
edad = 25
ultima_compra = 1000
premium = True

print ("Cliente: " + cliente)
print ("Edad: " + str(edad))
print ("Última compra: $" + str(ultima_compra))
print ("Premium: " + str(premium))
# Out:
# Cliente: Manuel Vazquez
# Edad: 25
# Última compra: $1000
# Premium: True

# %%
#ejercicio 2

# Datos del producto
nombre_producto = "Notebook"
marca = "Lenovo"
precio = 320000
stock = 8

etiqueta = marca + " " + nombre_producto + " | Precio: $" + str(precio) + " | Stock: " + str(stock) + " unidades"
print(etiqueta)
# Out:
# Lenovo Notebook | Precio: $320000 | Stock: 8 unidades

# %%
#ejercicio 3

precio_str = "15990"
descuento_str = "0.15"
cantidad_str = "4"
tiene_iva_str = "True"

precio = int(precio_str)
descuento = float(descuento_str)
cantidad = int(cantidad_str)
tiene_iva = bool(tiene_iva_str)

precio_final_sin_descuento = precio*4
precio_final_con_descuento = precio_final_sin_descuento - precio_final_sin_descuento * descuento
precio_final = None;

print(precio_final_sin_descuento)
print(precio_final_con_descuento)

if tiene_iva == True:
    precio_final = precio_final_con_descuento + precio_final_con_descuento*0.21

print(precio_final)
# Out:
# 63960
# 54366.0
# 65782.86

# %%
#ejercicio 4

fecha = "2024-11-14"
vendedor = "Carlos Méndez"
ventas = [45000, 32000, 67500, 28000, 91000]
producto_estrella = "Auriculares Bluetooth"

reporte = "Reporte de ventas - " + fecha + "\n" + "Vendedor: " + vendedor + "\n" + "Total ventas: $" + str(sum(ventas)) + "\n" + "Promedio por venta: $" + str(sum(ventas)/len(ventas)) + "\n" + "Producto estrella: " + producto_estrella

print(reporte)
# Out:
# Reporte de ventas - 2024-11-14
# Vendedor: Carlos Méndez
# Total ventas: $263500
# Promedio por venta: $52700.0
# Producto estrella: Auriculares Bluetooth

# %%
#ejercicio 5


usuarios_activos = "1523"
ingresos_totales = 847320.50
tasa_conversion = "3.7"
nombre_campania = "BlackFriday2024"

ingreso_por_usuario = ingresos_totales / int(usuarios_activos)
tasa_decimal = bool(tasa_conversion) / 100
resumen = "Campaña " + nombre_campania + " | Conversión: " + tasa_conversion + "% | Ingreso/usuario: $" + str(ingreso_por_usuario)
print(resumen)
# Out:
# Campaña BlackFriday2024 | Conversión: 3.7% | Ingreso/usuario: $556.34963887065

# %%
#ejercicio 6 

anio = 2024
pais = "AR"
tipo_transaccion = "compra"
numero = 847

transaction_id = str(anio)+"-"+pais+"-"+tipo_transaccion.upper()+"-"+str(numero).zfill(6)
print(transaction_id)
# Out:
# 2024-AR-COMPRA-000847

# %%
#ejercicio 7

valor_a = "42"
valor_b = "3.14"
valor_c = "True"
valor_d = ""
valor_e = "N/A"
valor_f = "  150  "
valor_g = "$1,250.50"
valor_h = "01/03/2024"

print(type(valor_a))
print(type(valor_b))
print(type(valor_c))
print(type(valor_d))
print(type(valor_e))
print(type(valor_f))
print(type(valor_g))
print(type(valor_h))

#conversiones
new_valor_a = str(valor_a)
new_valor_b = float(valor_b)
new_valor_c = bool(valor_c)
new_valor_d = None
new_valor_e = None
new_valor_f = int(valor_f.strip())
new_valor_g = float((valor_g.replace("$", "").replace(",", "")))
new_valor_h = valor_h.replace("/", "-")

print(new_valor_a)
print(new_valor_b)
print(new_valor_c)
print(new_valor_d)
print(new_valor_e)
print(new_valor_f)
print(new_valor_g)
print(new_valor_h)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 42
# 3.14
# True
# None
# None
# 150
# 1250.5
# 01-03-2024
